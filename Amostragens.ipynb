# %% [markdown]
# # **Amostragens**
#
# ### Importando as Bibliotecas

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

import warnings


warnings.filterwarnings('ignore')

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/enem_2019_tratados.csv', sep=',', encoding='iso-8859-1')
df
# Out:
#        NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  NU_IDADE TP_SEXO ESTADO CIVIL  \
# 0          1,90E+11            Santa Isabel        22       M  Solteiro(a)
# 1          1,90E+11               São Paulo        17       F  Solteiro(a)
# 2          1,90E+11   São Bernardo do Campo        19       M  Solteiro(a)
# 3          1,90E+11              Embu-Guaçu        17       F  Solteiro(a)
# 4          1,90E+11               Guarulhos        23       F  Solteiro(a)
# ...             ...                     ...       ...     ...          ...
# 499931     1,90E+11               São Paulo        18       F  Solteiro(a)
# 499932     1,90E+11               São Paulo        17       F  Solteiro(a)
# 499933     1,90E+11               São Paulo        17       F  Solteiro(a)
# 499934     1,90E+11               São Paulo        17       M  Solteiro(a)
# 499935     1,90E+11                  Araras        18       F  Solteiro(a)
#
# ...

# %%
enem_campinas = df.loc[df.NO_MUNICIPIO_RESIDENCIA == 'Campinas']
enem_campinas
# Out:
#        NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  NU_IDADE TP_SEXO ESTADO CIVIL  \
# 15         1,90E+11                Campinas        17       F  Solteiro(a)
# 31         1,90E+11                Campinas        19       F  Solteiro(a)
# 51         1,90E+11                Campinas        17       F  Solteiro(a)
# 116        1,90E+11                Campinas        17       F  Solteiro(a)
# 169        1,90E+11                Campinas        17       M  Solteiro(a)
# ...             ...                     ...       ...     ...          ...
# 499725     1,90E+11                Campinas        18       M  Solteiro(a)
# 499745     1,90E+11                Campinas        17       M  Solteiro(a)
# 499858     1,90E+11                Campinas        17       F  Solteiro(a)
# 499865     1,90E+11                Campinas        19       F  Solteiro(a)
# 499879     1,90E+11                Campinas        20       F  Solteiro(a)
#
# ...

# %% [markdown]
# ### **Amostragem aleatórias simples**

# %%
np.random.seed(1)

# %%
amos_simples = enem_campinas.sample(frac=0.20) # Porcentagem
amos_simples
# Out:
#        NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  NU_IDADE TP_SEXO   ESTADO CIVIL  \
# 327998     1,90E+11                Campinas        20       M    Solteiro(a)
# 235221     1,90E+11                Campinas        17       F    Solteiro(a)
# 134220     1,90E+11                Campinas        18       F    Solteiro(a)
# 358406     1,90E+11                Campinas        25       M  Não informado
# 173363     1,90E+11                Campinas        18       M    Solteiro(a)
# ...             ...                     ...       ...     ...            ...
# 452743     1,90E+11                Campinas        45       F    Solteiro(a)
# 362917     1,90E+11                Campinas        19       M    Solteiro(a)
# 221396     1,90E+11                Campinas        19       F    Solteiro(a)
# 76627      1,90E+11                Campinas        17       M  Não informado
# 126401     1,90E+11                Campinas        17       F    Solteiro(a)
#
# ...

# %%
amos_simples = enem_campinas.sample(3000) # Quantidade numérica
amos_simples
# Out:
#        NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  NU_IDADE TP_SEXO ESTADO CIVIL  \
# 57191      1,90E+11                Campinas        17       F  Solteiro(a)
# 215077     1,90E+11                Campinas        17       F  Solteiro(a)
# 430767     1,90E+11                Campinas        18       M  Solteiro(a)
# 409179     1,90E+11                Campinas        19       F  Solteiro(a)
# 429860     1,90E+11                Campinas        17       F  Solteiro(a)
# ...             ...                     ...       ...     ...          ...
# 238948     1,90E+11                Campinas        22       F  Solteiro(a)
# 242710     1,90E+11                Campinas        17       F  Solteiro(a)
# 467035     1,90E+11                Campinas        17       F  Solteiro(a)
# 189966     1,90E+11                Campinas        19       F  Solteiro(a)
# 282920     1,90E+11                Campinas        18       F  Solteiro(a)
#
# ...

# %% [markdown]
# ### **outra maneira**

# %%
np.random.seed(2)

# %%
amostra = np.random.choice(a=[0,1], size=13198, replace=True, p=[0.8, 0.2])
amostra
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %%
len(amostra[amostra == 0])
# Out:
# 10566

# %%
len(amostra[amostra == 1])
# Out:
# 2632

# %%
amos_simples = enem_campinas.loc[amostra == 1]

# %%
amos_simples
# Out:
#        NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  NU_IDADE TP_SEXO ESTADO CIVIL  \
# 949        1,90E+11                Campinas        17       F  Solteiro(a)
# 1058       1,90E+11                Campinas        19       M  Solteiro(a)
# 1980       1,90E+11                Campinas        17       F  Solteiro(a)
# 2053       1,90E+11                Campinas        18       F  Solteiro(a)
# 2328       1,90E+11                Campinas        20       F  Solteiro(a)
# ...             ...                     ...       ...     ...          ...
# 498942     1,90E+11                Campinas        17       M  Solteiro(a)
# 499194     1,90E+11                Campinas        18       M  Solteiro(a)
# 499254     1,90E+11                Campinas        21       F  Solteiro(a)
# 499687     1,90E+11                Campinas        17       F  Solteiro(a)
# 499879     1,90E+11                Campinas        20       F  Solteiro(a)
#
# ...

# %% [markdown]
# ### **Amostragem sistemática**

# %%
np.random.seed(2)
inicio = np.random.choice(10,1)
amostra2 = np.arange(inicio,13198,100)
amostra2
# Out:
# array([    8,   108,   208,   308,   408,   508,   608,   708,   808,
#          908,  1008,  1108,  1208,  1308,  1408,  1508,  1608,  1708,
#         1808,  1908,  2008,  2108,  2208,  2308,  2408,  2508,  2608,
#         2708,  2808,  2908,  3008,  3108,  3208,  3308,  3408,  3508,
#         3608,  3708,  3808,  3908,  4008,  4108,  4208,  4308,  4408,
#         4508,  4608,  4708,  4808,  4908,  5008,  5108,  5208,  5308,
#         5408,  5508,  5608,  5708,  5808,  5908,  6008,  6108,  6208,
#         6308,  6408,  6508,  6608,  6708,  6808,  6908,  7008,  7108,
#         7208,  7308,  7408,  7508,  7608,  7708,  7808,  7908,  8008,
#         8108,  8208,  8308,  8408,  8508,  8608,  8708,  8808,  8908,
#         9008,  9108,  9208,  9308,  9408,  9508,  9608,  9708,  9808,
#         9908, 10008, 10108, 10208, 10308, 10408, 10508, 10608, 10708,
#        10808, 10908, 11008, 11108, 11208, 11308, 11408, 11508, 11608,
# ...

# %%
amos_sistematica = enem_campinas.iloc[amostra2,:]

# %%
amos_sistematica
# Out:
#        NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  NU_IDADE TP_SEXO ESTADO CIVIL  \
# 401        1,90E+11                Campinas        18       F  Solteiro(a)
# 5079       1,90E+11                Campinas        18       F  Solteiro(a)
# 9218       1,90E+11                Campinas        19       F  Solteiro(a)
# 13685      1,90E+11                Campinas        20       M  Solteiro(a)
# 18239      1,90E+11                Campinas        20       M  Solteiro(a)
# ...             ...                     ...       ...     ...          ...
# 481890     1,90E+11                Campinas        34       M  Solteiro(a)
# 485801     1,90E+11                Campinas        16       F  Solteiro(a)
# 488954     1,90E+11                Campinas        19       F  Solteiro(a)
# 492622     1,90E+11                Campinas        21       M  Solteiro(a)
# 496406     1,90E+11                Campinas        19       M  Solteiro(a)
#
# ...

# %% [markdown]
# # **Outra maneira**

# %%
np.random.seed(30)

# %%
inicio = np.random.choice(10,1)
passo = np.random.randint(100,150,1)

# %%
inicio
# Out:
# array([5])

# %%
passo
# Out:
# array([137])

# %%
amostra3 = np.arange(inicio,13198,passo)
amostra3
# Out:
# array([    5,   142,   279,   416,   553,   690,   827,   964,  1101,
#         1238,  1375,  1512,  1649,  1786,  1923,  2060,  2197,  2334,
#         2471,  2608,  2745,  2882,  3019,  3156,  3293,  3430,  3567,
#         3704,  3841,  3978,  4115,  4252,  4389,  4526,  4663,  4800,
#         4937,  5074,  5211,  5348,  5485,  5622,  5759,  5896,  6033,
#         6170,  6307,  6444,  6581,  6718,  6855,  6992,  7129,  7266,
#         7403,  7540,  7677,  7814,  7951,  8088,  8225,  8362,  8499,
#         8636,  8773,  8910,  9047,  9184,  9321,  9458,  9595,  9732,
#         9869, 10006, 10143, 10280, 10417, 10554, 10691, 10828, 10965,
#        11102, 11239, 11376, 11513, 11650, 11787, 11924, 12061, 12198,
#        12335, 12472, 12609, 12746, 12883, 13020, 13157])

# %%
amostra3_camp = enem_campinas.iloc[amostra3,:]
amostra3_camp
# Out:
#        NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  NU_IDADE TP_SEXO  \
# 186        1,90E+11                Campinas        19       F
# 6519       1,90E+11                Campinas        26       M
# 12280      1,90E+11                Campinas        20       F
# 18436      1,90E+11                Campinas        22       F
# 23717      1,90E+11                Campinas        18       M
# ...             ...                     ...       ...     ...
# 478515     1,90E+11                Campinas        23       F
# 483427     1,90E+11                Campinas        18       F
# 488336     1,90E+11                Campinas        19       F
# 493176     1,90E+11                Campinas        33       F
# 498122     1,90E+11                Campinas        17       M
#
#                              ESTADO CIVIL TP_COR_RACA  TP_NACIONALIDADE  \
# 186                           Solteiro(a)      Branca                 1
# 6519                        Não informado       Preta                 1
# ...

# %% [markdown]
# # **Amostragem estratificada**

# %%
enem_campinas['TP_COR_RACA'].value_counts()
# Out:
# TP_COR_RACA
# Branca           7507
# Parda            3652
# Preta            1510
# Amarela           279
# Não declarado     205
# Indígena           45
# Name: count, dtype: int64

# %% [markdown]
# ### Para quantidade pequena de grupos

# %%
branca = enem_campinas.loc[enem_campinas.TP_COR_RACA == 'Branca'].sample(frac=0.10)
branca.shape
# Out:
# (751, 29)

# %%
parda = enem_campinas.loc[enem_campinas.TP_COR_RACA == 'Parda'].sample(frac=0.10)
parda.shape
# Out:
# (365, 29)

# %%
preta = enem_campinas.loc[enem_campinas.TP_COR_RACA == 'Preta'].sample(frac=0.10)
preta.shape
# Out:
# (151, 29)

# %%
amarela = enem_campinas.loc[enem_campinas.TP_COR_RACA == 'Amarela'].sample(frac=0.10)
amarela.shape
# Out:
# (28, 29)

# %%
nao_declarado = enem_campinas.loc[enem_campinas.TP_COR_RACA == 'Não declarado'].sample(frac=0.10)
nao_declarado.shape
# Out:
# (20, 29)

# %%
indigena = enem_campinas.loc[enem_campinas.TP_COR_RACA == 'Indígena'].sample(frac=0.10)
indigena.shape
# Out:
# (4, 29)

# %%
amostra_estra = pd.concat([branca,parda,preta,amarela,nao_declarado,indigena])
amostra_estra
# Out:
#        NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  NU_IDADE TP_SEXO   ESTADO CIVIL  \
# 439939     1,90E+11                Campinas        17       M    Solteiro(a)
# 477688     1,90E+11                Campinas        30       M    Solteiro(a)
# 398247     1,90E+11                Campinas        18       F    Solteiro(a)
# 121596     1,90E+11                Campinas        27       F  Não informado
# 316201     1,90E+11                Campinas        28       F    Solteiro(a)
# ...             ...                     ...       ...     ...            ...
# 424344     1,90E+11                Campinas        21       F    Solteiro(a)
# 88721      1,90E+11                Campinas        18       F    Solteiro(a)
# 315950     1,90E+11                Campinas        17       M    Solteiro(a)
# 270534     1,90E+11                Campinas        27       M    Solteiro(a)
# 88211      1,90E+11                Campinas        17       F    Solteiro(a)
#
# ...

# %% [markdown]
# # **Grandes quantidades de grupos**

# %%
x_treino, x_teste, y_treino,amos_estra = train_test_split(enem_campinas.drop('TP_COR_RACA',axis=1),enem_campinas['TP_COR_RACA'],stratify=enem_campinas['TP_COR_RACA'],test_size=0.20)

# %%
amos_estra.shape
# Out:
# (2640,)

# %%
amos_estra.value_counts()
# Out:
# TP_COR_RACA
# Branca           1502
# Parda             730
# Preta             302
# Amarela            56
# Não declarado      41
# Indígena            9
# Name: count, dtype: int64

# %%
amos_estra = amos_estra.index

# %%
amos_estra
# Out:
# Index([354700, 171453,  80881,  74735, 200885,  42542, 162153,  43460, 173203,
#        245994,
#        ...
#        497528, 328797, 484296, 292797, 239868, 310617, 486067, 172688, 109356,
#        145728],
#       dtype='int64', length=2640)

# %%
amos_estra_camp = enem_campinas.loc[amos_estra,:]

# %%
amos_estra_camp
# Out:
#        NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  NU_IDADE TP_SEXO  \
# 354700     1,90E+11                Campinas        18       F
# 171453     1,90E+11                Campinas        43       M
# 80881      1,90E+11                Campinas        17       F
# 74735      1,90E+11                Campinas        21       M
# 200885     1,90E+11                Campinas        21       M
# ...             ...                     ...       ...     ...
# 310617     1,90E+11                Campinas        56       F
# 486067     1,90E+11                Campinas        20       F
# 172688     1,90E+11                Campinas        17       M
# 109356     1,90E+11                Campinas        18       M
# 145728     1,90E+11                Campinas        18       F
#
#                                    ESTADO CIVIL TP_COR_RACA  TP_NACIONALIDADE  \
# 354700                              Solteiro(a)      Branca                 1
# ...

# %% [markdown]
# # **Amostragem por conglomerado(Agrupamento)**

# %%
escolas_publicas =enem_campinas.loc[enem_campinas.TP_ESCOLA == 'Pública']

# %%
escolas_publicas.shape
# Out:
# (4175, 29)

# %%
escolas_publicas
# Out:
#        NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  NU_IDADE TP_SEXO ESTADO CIVIL  \
# 51         1,90E+11                Campinas        17       F  Solteiro(a)
# 116        1,90E+11                Campinas        17       F  Solteiro(a)
# 325        1,90E+11                Campinas        17       M  Solteiro(a)
# 949        1,90E+11                Campinas        17       F  Solteiro(a)
# 1004       1,90E+11                Campinas        24       F  Solteiro(a)
# ...             ...                     ...       ...     ...          ...
# 499526     1,90E+11                Campinas        17       F  Solteiro(a)
# 499636     1,90E+11                Campinas        22       M  Solteiro(a)
# 499687     1,90E+11                Campinas        17       F  Solteiro(a)
# 499745     1,90E+11                Campinas        17       M  Solteiro(a)
# 499858     1,90E+11                Campinas        17       F  Solteiro(a)
#
# ...

# %%
amostras = escolas_publicas['CO_ESCOLA'].value_counts()
amostras.index
# Out:
# Index([35045937.0, 35018363.0, 35018797.0, 35018879.0, 35018326.0, 35047200.0,
#        35901097.0, 35045949.0, 35018235.0, 35018302.0,
#        ...
#        35018181.0, 35445757.0, 35045724.0, 35432842.0, 35039834.0, 35462822.0,
#        35058836.0, 35112926.0, 35017255.0, 35047053.0],
#       dtype='float64', name='CO_ESCOLA', length=186)
