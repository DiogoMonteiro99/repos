# %% [markdown]
# <a href="https://colab.research.google.com/github/DiogoMonteiro99/repos/blob/main/Amostragens.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Amostragens**
#
# ### Importando as Bibliotecas

# %%
import pandas as pd
import numpy as np

import warnings


warnings.filterwarnings('ignore')

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/enem_2019_tratados.csv', sep=',', encoding='iso-8859-1')
df
# Out:
#        NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  NU_IDADE TP_SEXO ESTADO CIVIL  \
# 0          1,90E+11            Santa Isabel        22       M  Solteiro(a)
# 1          1,90E+11               São Paulo        17       F  Solteiro(a)
# 2          1,90E+11   São Bernardo do Campo        19       M  Solteiro(a)
# 3          1,90E+11              Embu-Guaçu        17       F  Solteiro(a)
# 4          1,90E+11               Guarulhos        23       F  Solteiro(a)
# ...             ...                     ...       ...     ...          ...
# 499931     1,90E+11               São Paulo        18       F  Solteiro(a)
# 499932     1,90E+11               São Paulo        17       F  Solteiro(a)
# 499933     1,90E+11               São Paulo        17       F  Solteiro(a)
# 499934     1,90E+11               São Paulo        17       M  Solteiro(a)
# 499935     1,90E+11                  Araras        18       F  Solteiro(a)
#
# ...

# %%
enem_campinas = df.loc[df.NO_MUNICIPIO_RESIDENCIA == 'Campinas']
enem_campinas
# Out:
#        NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  NU_IDADE TP_SEXO ESTADO CIVIL  \
# 15         1,90E+11                Campinas        17       F  Solteiro(a)
# 31         1,90E+11                Campinas        19       F  Solteiro(a)
# 51         1,90E+11                Campinas        17       F  Solteiro(a)
# 116        1,90E+11                Campinas        17       F  Solteiro(a)
# 169        1,90E+11                Campinas        17       M  Solteiro(a)
# ...             ...                     ...       ...     ...          ...
# 499725     1,90E+11                Campinas        18       M  Solteiro(a)
# 499745     1,90E+11                Campinas        17       M  Solteiro(a)
# 499858     1,90E+11                Campinas        17       F  Solteiro(a)
# 499865     1,90E+11                Campinas        19       F  Solteiro(a)
# 499879     1,90E+11                Campinas        20       F  Solteiro(a)
#
# ...

# %% [markdown]
# ### **Amostragem aleatórias simples**

# %%
np.random.seed(1)

# %%
amos_simples = enem_campinas.sample(frac=0.20) # Porcentagem
amos_simples
# Out:
#        NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  NU_IDADE TP_SEXO   ESTADO CIVIL  \
# 327998     1,90E+11                Campinas        20       M    Solteiro(a)
# 235221     1,90E+11                Campinas        17       F    Solteiro(a)
# 134220     1,90E+11                Campinas        18       F    Solteiro(a)
# 358406     1,90E+11                Campinas        25       M  Não informado
# 173363     1,90E+11                Campinas        18       M    Solteiro(a)
# ...             ...                     ...       ...     ...            ...
# 452743     1,90E+11                Campinas        45       F    Solteiro(a)
# 362917     1,90E+11                Campinas        19       M    Solteiro(a)
# 221396     1,90E+11                Campinas        19       F    Solteiro(a)
# 76627      1,90E+11                Campinas        17       M  Não informado
# 126401     1,90E+11                Campinas        17       F    Solteiro(a)
#
# ...

# %%
amos_simples = enem_campinas.sample(3000) # Quantidade numérica
amos_simples
# Out:
#        NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  NU_IDADE TP_SEXO ESTADO CIVIL  \
# 57191      1,90E+11                Campinas        17       F  Solteiro(a)
# 215077     1,90E+11                Campinas        17       F  Solteiro(a)
# 430767     1,90E+11                Campinas        18       M  Solteiro(a)
# 409179     1,90E+11                Campinas        19       F  Solteiro(a)
# 429860     1,90E+11                Campinas        17       F  Solteiro(a)
# ...             ...                     ...       ...     ...          ...
# 238948     1,90E+11                Campinas        22       F  Solteiro(a)
# 242710     1,90E+11                Campinas        17       F  Solteiro(a)
# 467035     1,90E+11                Campinas        17       F  Solteiro(a)
# 189966     1,90E+11                Campinas        19       F  Solteiro(a)
# 282920     1,90E+11                Campinas        18       F  Solteiro(a)
#
# ...

# %% [markdown]
# ### **outra maneira**

# %%
np.random.seed(2)

# %%
amostra = np.random.choice(a=[0,1], size=13198, replace=True, p=[0.8, 0.2])
amostra
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
len(amostra[amostra == 0])
# Out:
# 10539

# %%
len(amostra[amostra == 1])
# Out:
# 2659

# %%
amos_simples = enem_campinas.loc[amostra == 1]

# %%
amos_simples
# Out:
#        NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  NU_IDADE TP_SEXO ESTADO CIVIL  \
# 116        1,90E+11                Campinas        17       F  Solteiro(a)
# 169        1,90E+11                Campinas        17       M  Solteiro(a)
# 550        1,90E+11                Campinas        17       F  Solteiro(a)
# 1058       1,90E+11                Campinas        19       M  Solteiro(a)
# 1355       1,90E+11                Campinas        24       F  Solteiro(a)
# ...             ...                     ...       ...     ...          ...
# 498760     1,90E+11                Campinas        18       F  Solteiro(a)
# 498822     1,90E+11                Campinas        19       F  Solteiro(a)
# 498910     1,90E+11                Campinas        18       F  Solteiro(a)
# 499526     1,90E+11                Campinas        17       F  Solteiro(a)
# 499636     1,90E+11                Campinas        22       M  Solteiro(a)
#
# ...

# %% [markdown]
# ### **Amostragem sistemática**

# %%
np.random.seed(2)
